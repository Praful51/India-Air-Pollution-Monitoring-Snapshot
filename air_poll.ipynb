# %%
import pandas as pd
df=pd.read_csv('air_poll.csv')

# %%
df.head()
# Out:
#   country  state   city                                     station  \
# 0   India  Bihar  Patna  Govt. High School Shikarpur, Patna - BSPCB
# 1   India  Bihar  Patna                     Muradpur, Patna - BSPCB
# 2   India  Bihar  Patna                     Muradpur, Patna - BSPCB
# 3   India  Bihar  Patna                    Samanpura, Patna - BSPCB
# 4   India  Bihar  Patna                    Samanpura, Patna - BSPCB
#
#            last_update   latitude  longitude pollutant_id  pollutant_min  \
# 0  24-08-2026 11:00:00  25.592539  85.227158          SO2           12.0
# 1  24-08-2026 11:00:00  25.619651  85.147382        PM2.5           40.0
# 2  24-08-2026 11:00:00  25.619651  85.147382        OZONE            5.0
# 3  24-08-2026 11:00:00  25.596727  85.085624        PM2.5           25.0
# 4  24-08-2026 11:00:00  25.596727  85.085624          NH3            4.0
#
#    pollutant_max  pollutant_avg
# 0           13.0           13.0
# 1           53.0           45.0
# ...

# %%
df.dtypes
# Out:
# country           object
# state             object
# city              object
# station           object
# last_update       object
# latitude         float64
# longitude        float64
# pollutant_id      object
# pollutant_min    float64
# pollutant_max    float64
# pollutant_avg    float64
# dtype: object

# %%
df.shape
# Out:
# (3472, 11)

# %%
df['last_update']=pd.to_datetime(df['last_update'],format="%d-%m-%Y %H:%M:%S").dt.date

# %%
df.head()
# Out:
#   country  state   city                                     station  \
# 0   India  Bihar  Patna  Govt. High School Shikarpur, Patna - BSPCB
# 1   India  Bihar  Patna                     Muradpur, Patna - BSPCB
# 2   India  Bihar  Patna                     Muradpur, Patna - BSPCB
# 3   India  Bihar  Patna                    Samanpura, Patna - BSPCB
# 4   India  Bihar  Patna                    Samanpura, Patna - BSPCB
#
#   last_update   latitude  longitude pollutant_id  pollutant_min  \
# 0  2026-08-24  25.592539  85.227158          SO2           12.0
# 1  2026-08-24  25.619651  85.147382        PM2.5           40.0
# 2  2026-08-24  25.619651  85.147382        OZONE            5.0
# 3  2026-08-24  25.596727  85.085624        PM2.5           25.0
# 4  2026-08-24  25.596727  85.085624          NH3            4.0
#
#    pollutant_max  pollutant_avg
# 0           13.0           13.0
# 1           53.0           45.0
# 2           43.0           16.0
# 3          239.0           90.0
# ...

# %%
df.isnull().sum()
# Out:
# country            0
# state              0
# city               0
# station            0
# last_update        0
# latitude           0
# longitude          0
# pollutant_id       0
# pollutant_min    323
# pollutant_max    323
# pollutant_avg    323
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#      country          state         city  \
# 13     India          Assam      Nalbari
# 25     India          Bihar       Munger
# 34     India          Bihar        Patna
# 59     India          Assam     Guwahati
# 65     India          Bihar    Bhagalpur
# ...      ...            ...          ...
# 3365   India     Tamil Nadu   Coimbatore
# 3367   India     Tamil Nadu    Cuddalore
# 3368   India     Tamil Nadu  Thoothukudi
# 3379   India    West Bengal     Durgapur
# 3439   India  Uttar Pradesh    Modinagar
#
#                                          station last_update   latitude  \
# 13                    Bata Chowk, Nalbari - PCBA  2026-08-24  26.446912
# 25                     Town Hall, Munger - BSPCB  2026-08-24  25.376776
# 34                 Rajbansi Nagar, Patna - BSPCB  2026-08-24  25.599486
# 59                   Pan Bazaar, Guwahati - PCBA  2026-08-24  26.187500
# 65    DM Office_Kachari Chowk, Bhagalpur - BSPCB  2026-08-24  25.251013
# ...

# %%
df['data_status'] = df[['pollutant_min', 'pollutant_max', 'pollutant_avg']].notna().all(axis=1).map({
    True: 'Available',
    False: 'Missing'
})

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#   country  state   city                                     station  \
# 0   India  Bihar  Patna  Govt. High School Shikarpur, Patna - BSPCB
# 1   India  Bihar  Patna                     Muradpur, Patna - BSPCB
# 2   India  Bihar  Patna                     Muradpur, Patna - BSPCB
# 3   India  Bihar  Patna                    Samanpura, Patna - BSPCB
# 4   India  Bihar  Patna                    Samanpura, Patna - BSPCB
#
#   last_update   latitude  longitude pollutant_id  pollutant_min  \
# 0  2026-08-24  25.592539  85.227158          SO2           12.0
# 1  2026-08-24  25.619651  85.147382        PM2.5           40.0
# 2  2026-08-24  25.619651  85.147382        OZONE            5.0
# 3  2026-08-24  25.596727  85.085624        PM2.5           25.0
# 4  2026-08-24  25.596727  85.085624          NH3            4.0
#
#    pollutant_max  pollutant_avg data_status
# 0           13.0           13.0   Available
# 1           53.0           45.0   Available
# ...

# %%
df['data_status'].value_counts()
# Out:
# data_status
# Available    3149
# Missing       323
# Name: count, dtype: int64

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:Prafulsql4266@localhost:3306/air_poll")

# Upload DataFrame to MySQL
df.to_sql(
    "air_poll",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 3472
